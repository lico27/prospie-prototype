# %% [markdown]
# # Evaluation

# %% [markdown]
# # Setup

# %%
import pandas as pd
from pathlib import Path
import os
import sys
import time
import krippendorff
from supabase import create_client
import matplotlib.pyplot as plt
import seaborn as sns
colours = sns.color_palette("Set2")
from dotenv import load_dotenv
import warnings
warnings.filterwarnings("ignore")
from sentence_transformers import SentenceTransformer

project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)
from utils import get_table_from_supabase, extract_classifications
from evaluation_utils import get_recipients_by_id, format_tests
from evaluation_logic import *

#get keys from env
load_dotenv()
url = os.getenv("SUPABASE_URL")
key = os.getenv("SUPABASE_KEY")

# %% [markdown]
# ----

# %% [markdown]
# # Retrieving Data from Checkpoints

# %%
#get checkpoint folder
checkpoint_folder = Path("./13.1_checkpoints/")

#get checkpoint
funders_df = pd.read_pickle(checkpoint_folder / "funders_df.pkl")
grants_df = pd.read_pickle(checkpoint_folder / "grants_df.pkl")
areas_df = pd.read_pickle(checkpoint_folder / "areas_df.pkl")
hierarchies_df = pd.read_pickle(checkpoint_folder / "hierarchies_df.pkl")
eval_df = pd.read_pickle(checkpoint_folder / "eval_df.pkl")

# %% [markdown]
# -----

# %% [markdown]
# # Retrieving Data from Supabase and Building Dataframes

# %% [markdown]
# I have imported the evaluation pairs dataframe that was built as part of the logic development, but it is missing data for rows where `is_recipient=False`. This is due to the way that the database was built; these charities had not been linked to any grants from the 360Giving API or extracted from accounts, so did not get fed through the entire database building process. I will run the same embedding and classification extraction processes for these rows that have been used for the user preparation in prior notebooks, to ensure that the evaluation funder-recipient pairs have all data necessary to calculate their alignment scores.

# %%
#get data for evaluation recipients
recipient_ids = eval_df["recipient_id"].unique()
recipients_df = get_recipients_by_id(url, key, recipient_ids)

# %% [markdown]
# ## Creation of Embeddings

# %%
model = SentenceTransformer("all-roberta-large-v1")
recipient_cols = ["recipient_name", "recipient_activities", "recipient_objectives"]
recipients_false = recipients_df[recipients_df["is_recipient"] == False].copy()
recipients_false["recipient_concat_em"] = None

if len(recipients_false) > 0:
    for col in recipient_cols:
        #replace nans with empty string
        texts = recipients_false[col].fillna("").tolist()
        embeddings = model.encode(texts)

        #add to df
        recipients_false[f"{col}_em"] = list(embeddings)

    recipients_false["concat_text"] = recipients_false[recipient_cols[0]].fillna("")
    for col in recipient_cols[1:]:
        recipients_false["concat_text"] += " " + recipients_false[col].fillna("")

    #make lowercase
    recipients_false["concat_text"] = recipients_false["concat_text"].str.lower()

    #create embeddings
    texts = recipients_false["concat_text"].tolist()
    embeddings = model.encode(texts)
    recipients_false["recipient_concat_em"] = list(embeddings)

    #drop concatenated text
    recipients_false = recipients_false.drop(columns=["concat_text"])

    embedding_cols = [f"{col}_em" for col in recipient_cols] + ["recipient_concat_em"]
    for col in embedding_cols:
        recipients_false.loc[recipients_false["is_recipient"] == False, col] = recipients_false[col].values

# %% [markdown]
# ## Creation of Extracted Classes

# %%
#load classifications data
ukcat_url = "https://raw.githubusercontent.com/lico27/ukcat/main/data/ukcat.csv"
ukcat_df = pd.read_csv(ukcat_url)

#define elements to process
recipient_sections = ["recipient_name", "recipient_objectives", "recipient_activities"]
keyword_data = [(recipients_false, recipient_sections, "recipient")]
recipients_false["extracted_class"] = recipients_false["recipient_areas"].copy()

#extract classifications
for df, sections, name in keyword_data:
    start_time = time.time()
    df["recipient_extracted_class"] = df.apply(lambda row: extract_classifications(row, sections, ukcat_df, areas_df), axis=1)
    elapsed_time = time.time() - start_time
    print(f"Classification extraction complete for {name}. Total time: {elapsed_time:.2f}s")
# Out:
# Classification extraction complete for recipient. Total time: 0.27s

# %%
#capitalise extracted classifications
recipients_false["recipient_extracted_class"] = recipients_false["recipient_extracted_class"].apply(lambda classifications: [phrase.upper() for phrase in classifications] if isinstance(classifications, list) else [])

#remove "grant making"
recipients_false["recipient_extracted_class"] = recipients_false["recipient_extracted_class"].apply(lambda classifications: [phrase for phrase in classifications if phrase != "GRANT MAKING"] if isinstance(classifications, list) else [])

#drop extra column
recipients_false = recipients_false.drop(columns=["extracted_class"])

# %% [markdown]
# ## The Final Evaluation Pairs Dataframe

# %%
#remove rows with missing data and concat recipients dfs
recipients_df = recipients_df[~recipients_df["recipient_id"].isin(recipients_false["recipient_id"])]
recipients_df = pd.concat([recipients_df, recipients_false], ignore_index=True)

#drop old recipient cols and add new to eval_df
recipient_cols = [col for col in eval_df.columns if col.startswith("recipient_") and col != "recipient_id"]
eval_df = eval_df.drop(columns=recipient_cols)
eval_df = eval_df.merge(recipients_df, on="recipient_id", how="left")
eval_df = eval_df.rename(columns=lambda col: f"user_{col[len('recipient_'):]}" if col.startswith("recipient_") else col)

# %%
pd.set_option("display.max_columns", None)
eval_df.head(1)
# Out:
#    id funder_registered_num  user_id                    name website  \
# 0   1                298633  1207372  BACON CHARITABLE TRUST    None
#
#                                           activities  \
# 0  MAKING DONATIONS TO SUCH CHARITABLE INSTITUTIO...
#
#                                           objectives  income_latest  \
# 0  TO APPLY THE INCOME AND ALL OR SUCH PART OR PA...        72879.0
#
#    expenditure_latest objectives_activities achievements_performance  \
# 0             72879.0                  None                     None
#
#   grant_policy  is_potential_sbf  is_on_list  is_nua  \
# 0         None             False       False   False
#
#                                              name_em  \
# 0  [0.004460917,0.035826597,-0.01591086,-0.011070...
#
#                                        activities_em  \
# 0  [-0.0064024967,0.037508424,-0.0025785645,-0.02...
#
#                                        objectives_em  \
# 0  [-0.024516284,0.022869943,-0.032995474,-0.0348...
#
#                             objectives_activities_em  \
# 0  [-0.019817753,-0.00571729,0.022262126,-0.03666...
#
#                          achievements_performance_em  \
# 0  [-0.019817753,-0.00571729,0.022262126,-0.03666...
#
#                                      grant_policy_em  \
# 0  [-0.019817753,-0.00571729,0.022262126,-0.03666...
#
#                                            concat_em   extracted_class  \
# 0  [-0.021681184,0.0020920401,0.009623636,-0.0578...  ["GRANT MAKING"]
#
#                                               causes                    areas  \
# 0  [General Charitable Purposes, Environment/cons...  [Lincolnshire, Norfolk]
#
#                            beneficiaries  \
# 0  [Other Charities Or Voluntary Bodies]
#
#                                       income_history  \
# 0  {2020: 23696.0, 2021: 27920.0, 2022: 242325.0,...
#
#                                  expenditure_history list_entries  \
# 0  {2020: 23696.0, 2021: 27920.0, 2022: 242325.0,...           []
#
#                            user_name  \
# 0  CATTON GROVE COMMUNITY CENTRE CIO
#
#                                      user_activities  is_recipient  \
# 0  CATTON GROVE COMMUNITY CENTRE SUPPORTS A WIDE ...         False
#
#                                      user_objectives  \
# 0  THE OBJECTS OF THE CIO ARE TO FURTHER BENEFIT ...
#
#                                         user_name_em  \
# 0  [0.006319203, 0.0067654094, -0.029557364, -0.0...
#
#                                   user_activities_em  \
# 0  [0.0027825288, -0.043152414, 0.016655156, -0.0...
#
#                                   user_objectives_em  \
# 0  [-0.011579754, 0.0077819657, -0.030523552, -0....
#
#                                       user_concat_em  \
# 0  [-0.02640823, 0.0003374529, 0.019409541, -0.04...
#
#                                 user_extracted_class user_areas   user_causes  \
# 0  [NORFOLK, COMMUNITY ASSOCIATION, COMMUNITY DEV...  [Norfolk]  [Recreation]
#
#                                   user_beneficiaries
# 0  [Children/young People, Elderly/old People, Pe...

# %% [markdown]
# ## Evaluation Responses

# %%
#get table from supabase
responses_df = get_table_from_supabase(url, key, "evaluation_responses")

#assign ids to respondents
responses_df["respondent_id"] = (responses_df["id"] - 61) // 3 + 1

# %% [markdown]
# ----

# %% [markdown]
# # Exploration of Raters' Responses

# %% [markdown]
# To understand the level of agreement among raters for each funder-recipient pair, I will create a boxplot showing the distribution of ratings. This will allow me to identify which pairs generated strong consensus among professional fundraisers, offering insight into whether there is inter-rater agreement so that I can gauge the usefulness of the feedback in evaluating prospie's performance.
#
# I will also calculate k-alpha for each pair (Krippendorff, 2019), which quantifies inter-rater reliability thereby indicating how consistent and useful the gathered evaluation data will be.

# %%
#group pairs
pair_ids = sorted(responses_df["pair_id"].unique())
data_by_pair = [responses_df[responses_df["pair_id"] == pair_id]["rating"].values for pair_id in pair_ids]

#create boxplot
fig, ax = plt.subplots(figsize=(12, 6))
bp = ax.boxplot(data_by_pair, labels=pair_ids, showfliers=True)

ax.set_title("Distribution of Ratings by Pair", fontsize=14, fontweight="bold")
ax.set_xlabel("Pair ID")
ax.set_ylabel("Rating")
ax.grid(True, alpha=0.3, axis="y")

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.hist(responses_df["rating"], bins=20, edgecolor="black", alpha=0.7, color=colours[0])
ax.set_xlabel("Rating")
ax.set_ylabel("Frequency")
ax.set_title("Rating Counts", fontsize=14, fontweight="bold")
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluation of Inter-Rater Reliability

# %%
#pivot to get table and calculate k-alpha
k_alpha_table = responses_df.pivot(index="respondent_id", columns="pair_id", values="rating")
ka = krippendorff.alpha(k_alpha_table.values, level_of_measurement="interval")
print(f"Krippendorff's Alpha: {ka:.2f}")
# Out:
# Krippendorff's Alpha: 0.52

# %% [markdown]
# ## Observations

# %% [markdown]
# The boxplot clearly visualises how much human ratings vary across most pairs. This is to be expected as α = 0.52. Most boxes are long, indicating a wide range of ratings, although there are some noteable outliers:
#
# - Pair 5 has a strong consensus around very low alignment - this pair was specifically chosen as a very clear bad match.
# - Having looked into pair 8, I can see that this is a single-beneficiary funder. The fact that it received a score above 80 suggests that perhaps a rater missed that restriction.
# - As the barchart shows, there was a greater consensus when it came to lower scores. It is evident that it is easier to interpret indicators of a very bad match; Pair 10, which has one of the largest ranges of scores, was actually well-matched due to a previous grants relationship although the funder states 'No Unsolicited Applications'. This highlights that a single piece of information can make the difference between a good and bad match - and if different raters spot or overlook different pieces of critical information, their scores will diverge significantly.
#
# This highlights a limitation of my evaluation approach: raters were given the same information that prospie has access to, but did not all make the same observations. These results further confirm that prospecting is not an exact science with objectively "correct" answers, but rather a nuanced judgement task where having access to transparent reasoning will potentially be substantially more important than receiving one single score.

# %% [markdown]
# -----

# %% [markdown]
# # Comparison of prospie Scores and Rater Scores

# %% [markdown]
# I will now calculate and display the prospie scores for the evaluation pairs. I will then create a scatterplot to visualise the relationship between the prospie scores and the means of the raters' scores, calculating Pearson's coefficient to understand the strength of any correlation.

# %%
#get scores for all pairs and display
for idx, row in eval_df.iterrows():
    result_v2 = calculate_alignment_score(eval_df, idx, grants_df, areas_df, hierarchies_df, model)
    format_tests(idx, row, result_v2)
# Out:
#     <div style="background: #1e1e1e; padding: 5px; margin: 5px 0; font-family: sans-serif; color: #d4d4d4;">
#         <div style="font-size: 16px; font-weight: bold; margin-bottom: 5px; color: #4ec9b0;">
#             #1: BACON CHARITABLE TRUST & CATTON GROVE COMMUNITY CENTRE CIO
#         </div>
#
#         <div style="display: grid; grid-template-columns: repeat(3, 1fr); gap: 5px; font-size: 13px;">
#             <div><span style="color: #808080;">prospie score:</span> 37.27%</div>
#         </div>
#
#     </div>
#     <div style="background: #1e1e1e; padding: 5px; margin: 5px 0; font-family: sans-serif; color: #d4d4d4;">
#         <div style="font-size: 16px; font-weight: bold; margin-bottom: 5px; color: #4ec9b0;">
#             #2: BEAVERBROOK FOUNDATION & FAITH IN LATER LIFE LTD
#         </div>
#
#         <div style="display: grid; grid-template-columns: repeat(3, 1fr); gap: 5px; font-size: 13px;">
#             <div><span style="color: #808080;">prospie score:</span> 60.43%</div>
#         </div>
#
#     </div>
#     <div style="background: #1e1e1e; padding: 5px; margin: 5px 0; font-family: sans-serif; color: #d4d4d4;">
#         <div style="font-size: 16px; font-weight: bold; margin-bottom: 5px; color: #4ec9b0;">
#             #3: JESSIE SPENCER TRUST & COMBAT STRESS
#         </div>
#
#         <div style="display: grid; grid-template-columns: repeat(3, 1fr); gap: 5px; font-size: 13px;">
#             <div><span style="color: #808080;">prospie score:</span> 86.45%</div>
#         </div>
#
#     </div>
#     <div style="background: #1e1e1e; padding: 5px; margin: 5px 0; font-family: sans-serif; color: #d4d4d4;">
#         <div style="font-size: 16px; font-weight: bold; margin-bottom: 5px; color: #4ec9b0;">
#             #4: GRUT TRUST & NORTHERN CANCER VOICES
#         </div>
#
#         <div style="display: grid; grid-template-columns: repeat(3, 1fr); gap: 5px; font-size: 13px;">
#             <div><span style="color: #808080;">prospie score:</span> 24.31%</div>
#         </div>
#
#     </div>
#     <div style="background: #1e1e1e; padding: 5px; margin: 5px 0; font-family: sans-serif; color: #d4d4d4;">
#         <div style="font-size: 16px; font-weight: bold; margin-bottom: 5px; color: #4ec9b0;">
#             #5: JOHN WHIPPY FOUNDATION & ANIMAL RESCUE CYMRU
#         </div>
#
#         <div style="display: grid; grid-template-columns: repeat(3, 1fr); gap: 5px; font-size: 13px;">
#             <div><span style="color: #808080;">prospie score:</span> 25.56%</div>
#         </div>
#
#     </div>
#     <div style="background: #1e1e1e; padding: 5px; margin: 5px 0; font-family: sans-serif; color: #d4d4d4;">
#         <div style="font-size: 16px; font-weight: bold; margin-bottom: 5px; color: #4ec9b0;">
#             #6: MRS WATERHOUSE CHARITABLE TRUST & KIDZ KLUB - LEEDS
#         </div>
#
#         <div style="display: grid; grid-template-columns: repeat(3, 1fr); gap: 5px; font-size: 13px;">
#             <div><span style="color: #808080;">prospie score:</span> 62.24%</div>
#         </div>
#
#     </div>
#     <div style="background: #1e1e1e; padding: 5px; margin: 5px 0; font-family: sans-serif; color: #d4d4d4;">
#         <div style="font-size: 16px; font-weight: bold; margin-bottom: 5px; color: #4ec9b0;">
#             #7: TESLER FOUNDATION & SEVENTH HEAVEN
#         </div>
#
#         <div style="display: grid; grid-template-columns: repeat(3, 1fr); gap: 5px; font-size: 13px;">
#             <div><span style="color: #808080;">prospie score:</span> 29.08%</div>
#         </div>
#
#     </div>
#     <div style="background: #1e1e1e; padding: 5px; margin: 5px 0; font-family: sans-serif; color: #d4d4d4;">
#         <div style="font-size: 16px; font-weight: bold; margin-bottom: 5px; color: #4ec9b0;">
#             #8: FRIENDS OF FAWLEY CHURCH & BERKSHIRE, BUCKINGHAMSHIRE AND OXFORDSHIRE WILDLIFE TRUST
#         </div>
#
#         <div style="display: grid; grid-template-columns: repeat(3, 1fr); gap: 5px; font-size: 13px;">
#             <div><span style="color: #808080;">prospie score:</span> 6.51%</div>
#         </div>
#
#     </div>
#     <div style="background: #1e1e1e; padding: 5px; margin: 5px 0; font-family: sans-serif; color: #d4d4d4;">
#         <div style="font-size: 16px; font-weight: bold; margin-bottom: 5px; color: #4ec9b0;">
#             #9: 3 TS CHARITABLE TRUST & WELDMAR HOSPICECARE
#         </div>
#
#         <div style="display: grid; grid-template-columns: repeat(3, 1fr); gap: 5px; font-size: 13px;">
#             <div><span style="color: #808080;">prospie score:</span> 7.31%</div>
#         </div>
#
#     </div>
#     <div style="background: #1e1e1e; padding: 5px; margin: 5px 0; font-family: sans-serif; color: #d4d4d4;">
#         <div style="font-size: 16px; font-weight: bold; margin-bottom: 5px; color: #4ec9b0;">
#             #10: DAVID AND RUTH BEHREND FUND & FREEDOM FROM TORTURE
#         </div>
#
#         <div style="display: grid; grid-template-columns: repeat(3, 1fr); gap: 5px; font-size: 13px;">
#             <div><span style="color: #808080;">prospie score:</span> 73.03%</div>
#         </div>
#
#     </div>
#     <div style="background: #1e1e1e; padding: 5px; margin: 5px 0; font-family: sans-serif; color: #d4d4d4;">
#         <div style="font-size: 16px; font-weight: bold; margin-bottom: 5px; color: #4ec9b0;">
#             #11: OSCAR MONTGOMERY ENVIRONMENTAL FOUNDATION & WILD TROUT TRUST LIMITED
#         </div>
#
#         <div style="display: grid; grid-template-columns: repeat(3, 1fr); gap: 5px; font-size: 13px;">
#             <div><span style="color: #808080;">prospie score:</span> 48.79%</div>
#         </div>
#
#     </div>
#     <div style="background: #1e1e1e; padding: 5px; margin: 5px 0; font-family: sans-serif; color: #d4d4d4;">
#         <div style="font-size: 16px; font-weight: bold; margin-bottom: 5px; color: #4ec9b0;">
#             #12: NINEVEH CHARITABLE TRUST & CANTERBURY CATHEDRAL TRUST FUND
#         </div>
#
#         <div style="display: grid; grid-template-columns: repeat(3, 1fr); gap: 5px; font-size: 13px;">
#             <div><span style="color: #808080;">prospie score:</span> 55.74%</div>
#         </div>
#
#     </div>

# %%
#store calculated scores
eval_df["calculated_score"] = eval_df.apply(
    lambda row: calculate_alignment_score(
        eval_df,
        row.name,
        grants_df,
        areas_df,
        hierarchies_df,
        model
    ),
    axis=1
)

#find mean rater scores and add to df
mean_ratings = responses_df.groupby("pair_id")["rating"].mean().reset_index()
mean_ratings.columns = ["id", "mean_rating"]
comparison_df = eval_df[["id", "calculated_score"]].merge(mean_ratings, on="id", how="inner")

#normalise mean rater scores
comparison_df["mean_rating_norm"] = ((comparison_df["mean_rating"] - 1) / 99) * 0.90 + 0.05

#create scatter plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(comparison_df["mean_rating_norm"], comparison_df["calculated_score"], alpha=0.6, s=100, color=colours[0])

#get pearsons r
corr = comparison_df["mean_rating_norm"].corr(comparison_df["calculated_score"])
plt.text(0.05, 0.95, f'r = {corr:.2f}', transform=plt.gca().transAxes,
        fontsize=12, verticalalignment="top")

#add labels
plt.xlabel("Mean Scores from Professional Fundraisers")
plt.ylabel("prospie's Calculated Alignment Score")
ax.set_title("prospie Score vs. Rater Scores", fontsize=14, fontweight="bold")
ax.grid(True, alpha=0.3)

#add line
plt.plot([0.05, 0.95], [0.05, 0.95], "r--", alpha=0.5, label="Perfect Agreement")
plt.legend()
plt.xlim(0, 1)
plt.ylim(0, 1)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Observations

# %% [markdown]
# The scatter plot shows a moderate positive correlation (r=0.47) between prospie's scores and the mean human ratings. Most pairs cluster reasonably near the line of perfect agreement, with both prospie and the human raters performing particularly well at identifying poor matches (bottom left cluster). The correlation of 0.47 is actually quite reasonable given that the raters only achieved α = 0.52 agreement with each other. Looking at this knowing the full context of each pair, prospie's scores generally reflect what I would expect - which suggests that it is applying the criteria more consistently than human raters who may have overlooked key details or rushed through the evaluation.

# %% [markdown]
# ----

# %% [markdown]
# # Validation of Scores with Historical Data

# %% [markdown]
# ## Test 1: Full Calculation (Known Funder-Recipient Pairs)

# %% [markdown]
# I will use the historical grants data in my database to create a validation set of funder-recipient pairs to test the accuracy of my alignment score calculation.
#
# First, I will create a sample of recent funders (from the past 10 years) who have given at least 20 grants.

# %%
#get sample
recent_sample = grants_df[grants_df["year"] >= 2015]
grant_counts = recent_sample.groupby("funder_num").size()
recent_funders = grant_counts[grant_counts >= 20].index.tolist()
recent_grants = recent_sample[recent_sample["funder_num"].isin(recent_funders)]

print(f"Eligible funders: {len(recent_funders)}")
print(f"Eligible grants: {len(recent_grants):,}")
# Out:
# Eligible funders: 155
# Eligible grants: 26,367

# %% [markdown]
# There are 155 eligible funders, who since 2015 have given a combined total of 26,367 grants. It would be too computationally expensive to calculate scores for all of these pairs, so I will use a random 10% sample of 2,636 pairs. I will exclude recipients that have been pulled from accounts without matching an existing registered charity, as they have the most missing data and do not, therefore, represent a comprehensive proxy of the data that a user will enter about their own charity (so do not offer as much value in testing the power and accuracy of the model).
#
# I will then combine the reduced `grants_df` with the relevant rows in `funders_df` to create the validation dataframe, before calling `calculate_alignment_score()` for each pair.

# %%
#get sample
grants_excluding_extracted = recent_grants[recent_grants["recipient_id"].astype(str).str[0].str.isdigit()]
validation_sample = grants_excluding_extracted.sample(n=2636, random_state=42)

#merge with funders
validation_df = validation_sample.merge(
    funders_df,
    left_on="funder_num",
    right_on="registered_num",
    how="inner"
)

#rename cols to match required format
validation_df = validation_df.rename(columns={"registered_num": "funder_registered_num"})
validation_df = validation_df.rename(columns=lambda col: f"user_{col[len('recipient_'):]}" if col.startswith("recipient_") else col)
validation_df = validation_df.rename(columns={"recipient_id": "user_id"})

# %%
#calculate scores for validation pairs
results = []

for idx, row in validation_df.iterrows():
    score = calculate_alignment_score(
        validation_df,
        idx,
        grants_df,
        areas_df,
        hierarchies_df,
        model
    )

    #store results
    results.append({
        "funder_num": row["funder_num"],
        "recipient_id": row["user_id"],
        "prospie_score": score,
        "actual_grant_amount": row["amount"],
        "year": row["year"]
    })

    #progress checkpoints
    if (len(results) % 200 == 0):
        print(f"Calculated {len(results)} scores")
# Out:
# Calculated 200 scores
# Calculated 400 scores
# Calculated 600 scores
# Calculated 800 scores
# Calculated 1000 scores
# Calculated 1200 scores
# Calculated 1400 scores
# Calculated 1600 scores
# Calculated 1800 scores
# Calculated 2000 scores
# Calculated 2200 scores
# Calculated 2400 scores
# Calculated 2600 scores

# %%
#get df of results and view stats
results_df = pd.DataFrame(results)
print(f"{results_df['prospie_score'].describe().round(2)}")
# Out:
# count    2636.00
# mean        0.83
# std         0.17
# min         0.05
# 25%         0.71
# 50%         0.95
# 75%         0.95
# max         0.95
# Name: prospie_score, dtype: float64

# %%
#view proportion of scores above thresholds
print(f"Proportion scoring >50%: {(results_df['prospie_score'] > 0.5).mean():.2%}")
print(f"Proportion scoring >60%: {(results_df['prospie_score'] > 0.6).mean():.2%}")
print(f"Proportion scoring >70%: {(results_df['prospie_score'] > 0.7).mean():.2%}")

#view overall averages
print(f"Mean: {results_df['prospie_score'].mean():.2f}")
print(f"Median: {results_df['prospie_score'].median():.2f}")
print(f"Mode: {results_df['prospie_score'].mode()[0]:.2f}")
# Out:
# Proportion scoring >50%: 93.17%
# Proportion scoring >60%: 83.50%
# Proportion scoring >70%: 75.95%
# Mean: 0.83
# Median: 0.95
# Mode: 0.95

# %%
#consider maximum scorers
num_95 = (results_df["prospie_score"] == 0.95).sum()
pct_95 = (results_df["prospie_score"] == 0.95).mean()
print(f"Pairs scoring 0.95: {num_95:,} ({pct_95:.1%})")

results_df["prospie_score"].hist(bins=10);
# Out:
# Pairs scoring 0.95: 1,450 (55.0%)

# %% [markdown]
# ### Observations

# %% [markdown]
# Looking at these scores, I notice that the mode is 0.95, and as the histogram shows, there is a large peak at pairs scoring 0.95 (representing 55% of the sample). This is expected as the validation dataset consists of funder-recipient pairs where grants were actually awarded, so many will have existing relationships that trigger the relationship bonus multiplier. To better understand the contribution of different components, I will run the validation again but this time exclude the existing relationship bonus.
#
# Promisingly, it does appear that prospie is performing well, with 76% of these known funder-recipient pairs achieving an alignment score of over 0.7.

# %%
#get checkpoint folder
checkpoint_folder = Path("./13.1_checkpoints/")

#create checkpoint - save df to pickle
# results_df.to_pickle(checkpoint_folder / "results_df.pkl")

#get checkpoint
results_df = pd.read_pickle(checkpoint_folder / "results_df.pkl")

# %% [markdown]
# ## Test 2: Calculation without Relationship Bonus (Known Funder-Recipient Pairs)

# %%
def calculate_relationship_bonus(relationship_df):
    """
    Calculates time since last grant and calculates a bonus. Only runs if there is a relationship.
    """

    #get time lapsed since last gift
    last_grant_year = relationship_df["year"].max()
    current_year = datetime.now().year
    time_lapsed = current_year - last_grant_year
    
    #assign bands
    if time_lapsed <= 2:
        bonus = 1.0
    elif time_lapsed <= 3:
        bonus = 1.0
    elif time_lapsed <= 5:
        bonus = 1.0
    elif time_lapsed <= 10:
        bonus = 1.0
    else:
        bonus = 1.0
    
    #add uplift for recurring relationship
    num_grants = len(relationship_df)
    if num_grants >= 5:
        bonus += 0.0
    
    return time_lapsed, bonus, last_grant_year

import evaluation_logic
evaluation_logic.calculate_relationship_bonus = calculate_relationship_bonus

# %%
#calculate scores for validation pairs
results_2 = []

for idx, row in validation_df.iterrows():
    score = calculate_alignment_score(
        validation_df,
        idx,
        grants_df,
        areas_df,
        hierarchies_df,
        model
    )

    #store results
    results_2.append({
        "funder_num": row["funder_num"],
        "recipient_id": row["user_id"],
        "prospie_score": score,
        "actual_grant_amount": row["amount"],
        "year": row["year"]
    })

    #progress checkpoints
    if (len(results_2) % 200 == 0):
        print(f"Calculated {len(results_2)} scores")
# Out:
# Calculated 200 scores
# Calculated 400 scores
# Calculated 600 scores
# Calculated 800 scores
# Calculated 1000 scores
# Calculated 1200 scores
# Calculated 1400 scores
# Calculated 1600 scores
# Calculated 1800 scores
# Calculated 2000 scores
# Calculated 2200 scores
# Calculated 2400 scores
# Calculated 2600 scores

# %%
#get df of results and view stats
results_2_df = pd.DataFrame(results_2)
print(f"{results_2_df['prospie_score'].describe().round(2)}")
# Out:
# count    2636.00
# mean        0.70
# std         0.22
# min         0.05
# 25%         0.50
# 50%         0.76
# 75%         0.91
# max         0.95
# Name: prospie_score, dtype: float64

# %%
#view proportion of scores above thresholds
print(f"Proportion scoring >50%: {(results_2_df['prospie_score'] > 0.5).mean():.2%}")
print(f"Proportion scoring >60%: {(results_2_df['prospie_score'] > 0.6).mean():.2%}")
print(f"Proportion scoring >70%: {(results_2_df['prospie_score'] > 0.7).mean():.2%}")

#view overall averages
print(f"Mean: {results_2_df['prospie_score'].mean():.2f}")
print(f"Median: {results_2_df['prospie_score'].median():.2f}")
print(f"Mode: {results_2_df['prospie_score'].mode()[0]:.2f}")
# Out:
# Proportion scoring >50%: 74.58%
# Proportion scoring >60%: 65.93%
# Proportion scoring >70%: 56.34%
# Mean: 0.70
# Median: 0.76
# Mode: 0.95

# %%
#consider maximum scorers
num_95 = (results_2_df["prospie_score"] == 0.95).sum()
pct_95 = (results_2_df["prospie_score"] == 0.95).mean()
print(f"Pairs scoring 0.95: {num_95:,} ({pct_95:.1%})")

results_2_df["prospie_score"].hist(bins=20);
# Out:
# Pairs scoring 0.95: 524 (19.9%)

# %% [markdown]
# ### Observations

# %% [markdown]
# These results make sense: far fewer pairs hit the 0.95 cap now (20% vs 55%), confirming that the existing relationship bonus was driving that concentration. The pairs still at 0.95 are genuinely strong matches across multiple dimensions, not just benefiting from relationship history.
#
# The histogram shows a bimodal distribution with peaks around 0.4 and 0.8-0.9. This is likely an artifact of the scoring mechanics - as various penalties (e.g. ×0.7) and bonuses (e.g. ×1.2) are applied to base alignment scores, they push scores towards certain bands. Different combinations of multipliers naturally create clustering at particular values rather than a smooth distribution.
#
# To better understand this pattern and establish a baseline for comparison, I will now create a set of 996 funder-recipient pairs, every funder matched with a random recipient, to see how the distribution differs from the validated set of actual pairs.

# %%
#create checkpoint - save df to pickle
# results_2_df.to_pickle(checkpoint_folder / "results_2_df.pkl")

#get checkpoint
results_2_df = pd.read_pickle(checkpoint_folder / "results_2_df.pkl")

# %% [markdown]
# ## Test 3: Baseline Distribution (Random Pairs)

# %%
#reimport functions with unchanged existing_relationship_bonus()
import importlib
import evaluation_logic
importlib.reload(evaluation_logic)
from evaluation_logic import *

# %%
#get all recipient ids
supabase = create_client(url, key)
all_recipient_ids = []
page_size = 1000
offset = 0

while True:
    response = supabase.table("recipients").select("recipient_id").range(offset, offset + page_size - 1).execute()
    if not response.data:
        break  

    all_recipient_ids.extend([row["recipient_id"] for row in response.data])
    offset += page_size

    if offset % 20000 == 0:
        print(f"Got {len(all_recipient_ids)} recipient IDs")

#get sample of 2000 recipients
random_recipient_ids = pd.Series(all_recipient_ids).sample(n=996, random_state=42).tolist()
# Out:
# Got 20000 recipient IDs
# Got 40000 recipient IDs
# Got 60000 recipient IDs
# Got 80000 recipient IDs
# Got 100000 recipient IDs
# Got 120000 recipient IDs
# Got 140000 recipient IDs
# Got 160000 recipient IDs
# Got 180000 recipient IDs

# %%
#get random recipients
random_recipients_df = get_recipients_by_id(url, key, random_recipient_ids)

# %% [markdown]
# ### Creation of Embeddings

# %%
recipient_cols = ["recipient_name", "recipient_activities", "recipient_objectives"]
recipients_with_em = random_recipients_df[random_recipients_df["recipient_name_em"].notna()].copy()
recipients_without_em = random_recipients_df[random_recipients_df["recipient_name_em"].isna()].copy()
recipients_without_em["recipient_concat_em"] = None

if len(recipients_without_em) > 0:
    for col in recipient_cols:
        #replace nans with empty string
        texts = recipients_without_em[col].fillna("").tolist()
        embeddings = model.encode(texts)

        #add to df
        recipients_without_em[f"{col}_em"] = list(embeddings)

    recipients_without_em["concat_text"] = recipients_without_em[recipient_cols[0]].fillna("")
    for col in recipient_cols[1:]:
        recipients_without_em["concat_text"] += " " + recipients_without_em[col].fillna("")

    #make lowercase
    recipients_without_em["concat_text"] = recipients_without_em["concat_text"].str.lower()

    #create embeddings
    texts = recipients_without_em["concat_text"].tolist()
    embeddings = model.encode(texts)
    recipients_without_em["recipient_concat_em"] = list(embeddings)

    #drop concatenated text
    recipients_without_em = recipients_without_em.drop(columns=["concat_text"])

# %% [markdown]
# ### Creation of Extracted Classifications

# %%
#load classifications data (if not already loaded)
if 'ukcat_df' not in locals():
    ukcat_url = "https://raw.githubusercontent.com/lico27/ukcat/main/data/ukcat.csv"
    ukcat_df = pd.read_csv(ukcat_url)

#define elements to process
recipient_sections = ["recipient_name", "recipient_objectives", "recipient_activities"]
keyword_data = [(recipients_without_em, recipient_sections, "recipient")]
recipients_without_em["extracted_class"] = recipients_without_em["recipient_areas"].copy()

#extract classifications
for df, sections, name in keyword_data:
    start_time = time.time()
    df["recipient_extracted_class"] = df.apply(lambda row: extract_classifications(row, sections, ukcat_df, areas_df), axis=1)
    elapsed_time = time.time() - start_time
    print(f"Classification extraction complete for {name}. Total time: {elapsed_time:.2f}s")
# Out:
# Classification extraction complete for recipient. Total time: 58.17s

# %%
#capitalise extracted classifications
recipients_without_em["recipient_extracted_class"] = recipients_without_em["recipient_extracted_class"].apply(lambda classifications: [phrase.upper() for phrase in classifications] if isinstance(classifications, list) else [])

#remove "grant making"
recipients_without_em["recipient_extracted_class"] = recipients_without_em["recipient_extracted_class"].apply(lambda classifications: [phrase for phrase in classifications if phrase != "GRANT MAKING"] if isinstance(classifications, list) else [])

#recombine
random_recipients_df = pd.concat([recipients_with_em, recipients_without_em], ignore_index=True)

#drop extra column
random_recipients_df = random_recipients_df.drop(columns=["extracted_class"])

# %%
random_recipients_df.shape
# Out:
# (996, 13)

# %% [markdown]
# ### Baseline Dataframe

# %%
#shuffle recipients and funders
shuffled_recipients = random_recipients_df.sample(frac=1, random_state=42).reset_index(drop=True)
shuffled_funders = funders_df.sample(frac=1, random_state=42).reset_index(drop=True)

#join as random pairs
random_validation_df = shuffled_funders.rename(columns={"registered_num": "funder_registered_num"})
random_validation_df["user_id"] = shuffled_recipients["recipient_id"].values
random_validation_df = random_validation_df.merge(
    shuffled_recipients.rename(columns=lambda col: f"user_{col[len('recipient_'):]}" if col.startswith("recipient_") else col),
    left_on="user_id",
    right_on="user_id",
    how="inner"
)
random_validation_df["funder_num"] = random_validation_df["funder_registered_num"]

# %%
pd.set_option("display.max_columns", None)
random_validation_df.head()
# Out:
#   funder_registered_num                                  name  \
# 0                278425                           FREE SCHOOL
# 1                527455        LLOYD'S EDUCATIONAL FOUNDATION
# 2               1069996  SUPPORT TIFFIN GIRLS' SCHOOL COMPANY
# 3               1198947    HAWKS AND OSPREYS CHARITABLE TRUST
# 4               1174672                HACHNOSAS ORCHIM TRUST
#
#                        website  \
# 0                         None
# 1                         None
# 2                         None
# 3  https://www.hawksclub.co.uk
# 4                         None
#
#                                           activities  \
# 0  OWNERSHIP OF THE SCHOOL PREMESIS AND PROVIDING...
# 1  FINANCIAL ASSISTANCE, CLOTHING, TOOLS, INSTRUM...
# 2  TO ADVANCE THE EDUCATION OF THE PUPILS AT TIFF...
# 3                               GRANT MAKING CHARITY
# 4  RELIGIOUS ACTIVITIES, EDUCATION/TRAINING, PREV...
#
#                                           objectives  income_latest  \
# 0  FOR THE PURPOSE OF PROVIDING ITEMS, SERVICES A...        21412.0
# 1  MAINTENANCE OF THE TWO SCHOOLS OF THE FOUNDATI...        21867.0
# 2  TO ADVANCE THE EDUCATION OF THE STUDENTS AT TH...       288379.0
# 3  A) TO ADVANCE THE EDUCATION OF STUDENTS OF THE...      1401890.0
# 4  FOR THE PUBLIC BENEFIT TO PROMOTE THE EDUCATIO...       190000.0
#
#    expenditure_latest objectives_activities achievements_performance  \
# 0              1329.0                  None                     None
# 1             38603.0                  None                     None
# 2            166911.0                  None                     None
# 3            103426.0                  None                     None
# 4            185000.0                  None                     None
#
#   grant_policy  is_potential_sbf  is_on_list  is_nua  \
# 0         None              True       False   False
# 1         None             False       False   False
# 2         None              True       False   False
# 3         None             False       False   False
# 4         None             False       False   False
#
#                                              name_em  \
# 0  [-0.03351756,0.011323113,0.0030659582,-0.01323...
# 1  [0.018302912,0.04287732,-0.028952345,-0.007711...
# 2  [0.010827602,-0.00037006408,-0.00949459,-0.019...
# 3  [0.0052049896,0.013556178,-0.033415295,-0.0146...
# 4  [0.011362906,0.024384223,-0.017764838,0.008849...
#
#                                        activities_em  \
# 0  [-0.06021438,0.0038445725,-0.014431287,-0.0573...
# 1  [-0.005929309,-0.034708146,-0.0057365163,-0.01...
# 2  [0.019324677,0.03823721,-0.011978641,-0.064712...
# 3  [0.004226071,0.05980014,-0.03009765,-0.0163691...
# 4  [0.012649966,0.029929765,0.012786655,0.0001298...
#
#                                        objectives_em  \
# 0  [-0.051732384,0.006662785,-0.0031588671,-0.043...
# 1  [-0.025794694,0.0013694443,-0.021835916,-0.048...
# 2  [0.02279446,0.027669163,-0.036067024,-0.045058...
# 3  [0.015836995,0.022254877,-0.031885587,-0.03662...
# 4  [-0.0072260317,0.0272896,-0.029438725,-0.01784...
#
#                             objectives_activities_em  \
# 0  [-0.019817753,-0.00571729,0.022262126,-0.03666...
# 1  [-0.019817753,-0.00571729,0.022262126,-0.03666...
# 2  [-0.019817753,-0.00571729,0.022262126,-0.03666...
# 3  [-0.019817753,-0.00571729,0.022262126,-0.03666...
# 4  [-0.019817753,-0.00571729,0.022262126,-0.03666...
#
#                          achievements_performance_em  \
# 0  [-0.019817753,-0.00571729,0.022262126,-0.03666...
# 1  [-0.019817753,-0.00571729,0.022262126,-0.03666...
# 2  [-0.019817753,-0.00571729,0.022262126,-0.03666...
# 3  [-0.019817803,-0.005717266,0.022262082,-0.0366...
# 4  [-0.019817753,-0.00571729,0.022262126,-0.03666...
#
#                                      grant_policy_em  \
# 0  [-0.019817753,-0.00571729,0.022262126,-0.03666...
# 1  [-0.019817753,-0.00571729,0.022262126,-0.03666...
# 2  [-0.019817753,-0.00571729,0.022262126,-0.03666...
# 3  [-0.019817753,-0.00571729,0.022262126,-0.03666...
# 4  [-0.019817753,-0.00571729,0.022262126,-0.03666...
#
#                                            concat_em  \
# 0  [-0.06414622,-0.0006856422,-0.004921216,-0.055...
# 1  [-0.049777627,-0.01115944,0.012942305,-0.03759...
# 2  [0.020310216,0.025097433,0.0007514197,-0.06492...
# 3  [-0.0025094994,-0.0038978762,0.0010129382,-0.0...
# 4  [-0.018667744,0.010218529,-0.007296019,-0.0081...
#
#                                      extracted_class  \
# 0                                        ["SCHOOLS"]
# 1  ["LITERATURE","YOUNG PEOPLE","GRANT MAKING","E...
# 2  ["ARTS","MUSIC","GIRLS","WOMEN","GRANT MAKING"...
# 3  ["PARENTS AND GUARDIANS","YOUNG PEOPLE","GRANT...
# 4  ["GRANT MAKING","GRANTS TO ORGANISATIONS","CHA...
#
#                                               causes                 areas  \
# 0                               [Education/training]     [Gloucestershire]
# 1  [General Charitable Purposes, Education/training]      [Worcestershire]
# 2                               [Education/training]   [Throughout London]
# 3                [Education/training, Amateur Sport]      [Cambridgeshire]
# 4  [Education/training, The Prevention Or Relief ...  [Throughout England]
#
#                                        beneficiaries  \
# 0                            [Children/young People]
# 1  [Children/young People, People With Disabilities]
# 2                            [Children/young People]
# 3                             [Other Defined Groups]
# 4  [Children/young People, The General Public/man...
#
#                                       income_history  \
# 0  {2020: 9446.0, 2021: 10961.0, 2022: 11282.0, 2...
# 1  {2020: 19994.0, 2021: 20368.0, 2022: 20305.0, ...
# 2  {2020: 309699.0, 2021: 263059.0, 2022: 315786....
# 3                       {2023: 0.0, 2024: 1401890.0}
# 4  {2020: 157874.0, 2021: 358520.0, 2022: 360000....
#
#                                  expenditure_history list_entries  user_id  \
# 0  {2020: 13104.0, 2021: 1194.0, 2022: 1189.0, 20...           []   274491
# 1  {2020: 15972.0, 2021: 16763.0, 2022: 16112.0, ...           []   701570
# 2  {2020: 302175.0, 2021: 538339.0, 2022: 151794....           []  1001560
# 3                        {2023: 0.0, 2024: 103426.0}           []  1187966
# 4  {2020: 148000.0, 2021: 350000.0, 2022: 348000....           []  1154999
#
#                                            user_name  \
# 0  MR R G DE GROOT ZENA DE GROOT AND MR D I DE GR...
# 1                           ABERFAN MEMORIAL CHARITY
# 2                      BRIGHTON TOY AND MODEL MUSEUM
# 3                            NORTHCHAPEL SPORTS CLUB
# 4      TUMAINI CHILDRENS CHARITY (HOPE FOR CHILDREN)
#
#                                      user_activities  is_recipient  \
# 0          MAKE DONATIONS TO CHARITABLE INSTITUTIONS         False
# 1  MAINTENANCE AND REPAIR OF CEMETERY MEMORIALS A...         False
# 2  THE BRIGHTON TOY AND MODEL MUSEUM EXHIBITS AND...         False
# 3  TO PROMOTE FOR THE BENEFIT OF THE INHABITANTS ...         False
# 4  WE CONTINUE TO FUND RAISE AND COLLECT MONTHLY ...         False
#
#                                      user_objectives  \
# 0  FOR THE BENEFIT OF SUCH OR MORE CHARITIES CHAR...
# 1  A) FOR THE MAINTENANCE AND REPAIR OF THE MEMOR...
# 2  TO ADVANCE THE EDUCATION OF THE GENERAL PUBLIC...
# 3  THE OBJECT OF THE CIO IS:TO PROMOTE FOR THE BE...
# 4  TO RELIEVE POVERTY IN KENYA BY PROVIDING EDUCA...
#
#                                         user_name_em  \
# 0  [0.052458357, 0.023156088, -0.0044115763, -0.0...
# 1  [0.006788731, 0.026461521, -0.024759505, -0.04...
# 2  [-0.010290138, 0.019951852, -0.019137139, -0.0...
# 3  [-0.015156715, -0.017254181, -0.027635446, -0....
# 4  [0.0040490697, -0.02296638, -0.059296772, -0.0...
#
#                                   user_activities_em  \
# 0  [-0.009739775, 0.057758756, -0.017919093, -0.0...
# 1  [0.019028526, 0.032914255, -0.041863516, -0.07...
# 2  [-0.022826362, 0.034437913, -0.0074157044, -0....
# 3  [-0.05514765, 0.018585386, -0.038681306, -0.05...
# 4  [0.024336265, 0.0014724857, -0.01721558, -0.03...
#
#                                   user_objectives_em  \
# 0  [-0.0022280717, 0.030820081, -0.020489639, -0....
# 1  [-0.006572179, 0.06664353, -0.017369999, -0.08...
# 2  [-0.0028732773, 0.044730905, -0.01219382, -0.0...
# 3  [-0.024134906, 0.0379701, -0.0511516, -0.04345...
# 4  [0.02812884, 0.046284337, -0.029951738, -0.015...
#
#                                       user_concat_em  \
# 0  [0.00011496376, -0.021761237, 0.0049665878, 0....
# 1  [0.018972978, -0.0038720514, 0.012020444, -0.1...
# 2  [-0.033393547, -0.0266847, 0.04249168, 0.01871...
# 3  [-0.0430478, -0.009258199, -0.01239029, -0.068...
# 4  [-0.0035896758, -0.0060420306, -0.028974023, -...
#
#                                 user_extracted_class user_areas  \
# 0                          [CHARITY AND VCS SUPPORT]         []
# 1  [CEMETERY, GREEN SPACE, HISTORICAL CONSERVATIO...         []
# 2                                [EDUCATION, MUSEUM]         []
# 3  [ASSOCIATIONS, YOUNG PEOPLE, RECREATION, SPORT...         []
# 4  [CHILDREN, FUNDRAISING, EDUCATION, HEALTH, FOO...         []
#
#                                          user_causes  \
# 0                                                 []
# 1                                                 []
# 2  [Education/training, Arts/culture/heritage/sci...
# 3                                                 []
# 4                                                 []
#
#                                   user_beneficiaries funder_num
# 0                                                 []     278425
# 1                                                 []     527455
# 2  [Children/young People, Elderly/old People, Pe...    1069996
# 3                                                 []    1198947
# 4                            [Children/young People]    1174672

# %%
#calculate scores for validation pairs
results_3 = []

for idx, row in random_validation_df.iterrows():
    score = calculate_alignment_score(
        random_validation_df,
        idx,
        grants_df,
        areas_df,
        hierarchies_df,
        model
    )

    results_3.append({
        "funder_num": row["funder_num"],
        "recipient_id": row["user_id"],
        "prospie_score": score
    })

    #progress checkpoints
    if (len(results_3) % 200 == 0):
        print(f"Calculated {len(results_3)} scores")
# Out:
# Calculated 200 scores
# Calculated 400 scores
# Calculated 600 scores
# Calculated 800 scores

# %%
#get df of results and view stats
results_3_df = pd.DataFrame(results_3)
print(f"{results_3_df['prospie_score'].describe().round(2)}")
# Out:
# count    996.00
# mean       0.26
# std        0.14
# min        0.05
# 25%        0.18
# 50%        0.25
# 75%        0.34
# max        0.76
# Name: prospie_score, dtype: float64

# %%
#view proportion of scores above thresholds
print(f"Proportion scoring >50%: {(results_3_df['prospie_score'] > 0.5).mean():.2%}")
print(f"Proportion scoring >60%: {(results_3_df['prospie_score'] > 0.6).mean():.2%}")
print(f"Proportion scoring >70%: {(results_3_df['prospie_score'] > 0.7).mean():.2%}")

#view overall averages
print(f"Mean: {results_3_df['prospie_score'].mean():.2f}")
print(f"Median: {results_3_df['prospie_score'].median():.2f}")
print(f"Mode: {results_3_df['prospie_score'].mode()[0]:.2f}")
# Out:
# Proportion scoring >50%: 4.72%
# Proportion scoring >60%: 0.90%
# Proportion scoring >70%: 0.10%
# Mean: 0.26
# Median: 0.25
# Mode: 0.05

# %%
#consider miniimum scorers
num_5 = (results_3_df["prospie_score"] == 0.05).sum()
pct_5 = (results_3_df["prospie_score"] == 0.05).mean()
print(f"Pairs scoring 0.05: {num_5:,} ({pct_5:.1%})")

results_3_df["prospie_score"].hist(bins=30);
# Out:
# Pairs scoring 0.05: 121 (12.1%)

# %% [markdown]
# ### Observations

# %% [markdown]
# To establish a baseline, I scored 996 random funder-recipient pairs (mean: 0.26, only 5% exceeding 50% alignment). This contrasts sharply with actual grant recipients (mean: 0.70, 75% exceeding 50%), demonstrating that prospie can effectively discern actual quality relationships versus random pairings. I am satisfied that this validates that the scoring logic produces meaningful results about funder-recipient alignment. prospie's ability to distinguish actual recipients (mean: 0.70) from random pairs (mean: 0.26) demonstrates that it can effectively filter signal from noise.
